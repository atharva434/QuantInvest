# %%
import pandas as pd

# %%
df = pd.read_csv("static/list.csv")

# %%
df
# Out:
#      Unnamed: 0 Stock_code                              SN  Lot_size  Status  \
# 0         16541     CNXBAN                      NIFTY BANK        30       0
# 1         16544     NIFFIN  NIFTY FINANCIAL SERVICES INDEX        65       0
# 2         16546     NIFNEX                   NIFTY NEXT 50        25       0
# 3         16548     NIFSEL             NIFTY MIDCAP SELECT       120       0
# 4         16551      NIFTY                        NIFTY 50        75       0
# ..          ...        ...                             ...       ...     ...
# 217       17206     VEDLIM                 VEDANTA LIMITED      1150       1
# 218       17209     VOLTAS                      VOLTAS LTD       300       1
# 219       17212      WIPRO                       WIPRO LTD      3000       1
# 220       17215     YESBAN                YES BANK LIMITED     26000       1
# 221       17222     ZOMLIM                  ZOMATO LIMITED      2000       1
#
# ...

# %%
df["Expiry_date"] = "2025-07-31"

# %%
df.to_csv("static/list.csv")
